# %% [markdown]
# <a href="https://colab.research.google.com/github/naharkalitaadtu09-code/Bus-booking-website/blob/main/nahar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f=open('demo.txt',"w") #to create a file
f.write("HI ADTU people")
f.close()

# %%
f=open('demo.txt',"a") #to create a file
f.write("\nAWESOME ASSAM")
f.close()

# %%
#TO edit exixted file
with open("main.txt","r+") as f:#context manager
print(f.read())

# %%
import numpy
a=numpy.arange(5)
a.shape
a.ndim
a.astype("int8")
# Out:
# array([0, 1, 2, 3, 4], dtype=int8)

# %%
a=numpy.arange(5)
a.dtype
a.astype("int8") #return a copy
# Out:
# array([0, 1, 2, 3, 4], dtype=int8)

# %%
arr=np.array([3,4,"Dev",6,7,8,9])
arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1113/651790850.py in <cell line: 0>()
# ----> 1 arr=np.array([3,4,"Dev",6,7,8,9])
#       2 arr
#
# NameError: name 'np' is not defined
